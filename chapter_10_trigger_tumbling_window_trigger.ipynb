# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## tumbling window trigger can go back to the past data and take that data and can be run, i'e historical data

# %% [markdown]
# ## dependancy concept is not there in this trigger

# %% [markdown]
# ## desitination

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - you can see in modifies all files are modifiying again and again even in source if 1 file is added that is issue, because already existing file if doing steps anagin and again means so many cost will occur

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - in source only one file is added but in modifies all files are modified that is issue, because already existing file if doing steps anagin and again means so many cost will occur

# %% [markdown]
# - 1 st create two paramenters for pipeline like start_time and end_tme
# - 2nd create new trigger tumbling window trigger
# - 3rd give @trigger().output.windowStartTime and @trigger().output.windowEndTime in start_time and end_time paramenters

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## now in source strt-time and end-time give

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # now only one file is gettng loaded

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
