# %% [markdown]
# # two methods we can do copy activity one by automatic like this

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - by clicking copy data and then we can choose the source and destination and then we can choose the data and then we can choose the schedule and then we can choose the name and then we can click on create and then we can see the pipeline is created and then we can run the pipeline and then we can see the data is copied to the destination.

# %% [markdown]
# - It will create automatically
#     - Integration runtime
#     - Linked service
#     - Dataset
# - It will complete pipeline for us and then we can run the pipeline and then we can see the data is copied to the destination.

# %% [markdown]
# # method 2 ->  most used is by creating manually

# %% [markdown]
# - 1st create linked service for source and destination
# - 2nd create dataset for source and destination
# - check Integration runtime is created or not if not then create it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## then create pipeline

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - using debug we can run the pipeline and then we can see the data is copied to the destination.
