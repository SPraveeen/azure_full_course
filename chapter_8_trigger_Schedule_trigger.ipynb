# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## In manage tab triggers can be seen

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## under monitor tab we can see the trigger runs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## undermanage tab we can stop the trigger

# %% [markdown]
# ![image.png](attachment:image.png)
