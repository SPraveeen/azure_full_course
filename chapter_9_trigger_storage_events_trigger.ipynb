# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## in case of adding any new files or some changes ie events we call then this pipeline will run automatically

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## create parameter to pass source value as variable format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 1st create parameter for pipeline
# - 2nd pass that parameter to trigger
# - then in source create paramater and pass the value from trigger parameter
